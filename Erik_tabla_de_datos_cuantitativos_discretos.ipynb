# %% [markdown]
# [VOLVER AL INDICE](https://github.com/Miguel0ro/Tablas-de-frecuencia)

# %%
# Importar librerías
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Generar datos aleatorios
np.random.seed(0)  # Para reproducibilidad
data = np.random.randint(1, 25, size=500)  # Datos discretos entre 1 y 100

# Crear un DataFrame
df = pd.DataFrame(data, columns=['Valores'])

# Calcular frecuencias
frecuencia_absoluta = df['Valores'].value_counts().sort_index()
frecuencia_relativa = frecuencia_absoluta / len(df)
frecuencia_acumulada = frecuencia_absoluta.cumsum()

# Crear gráficos

# Histograma de frecuencia absoluta
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
plt.hist(df['Valores'], bins=20, color='blue', alpha=0.7)
plt.title('Histograma de Frecuencia Absoluta')
plt.xlabel('Valores')
plt.ylabel('Frecuencia Absoluta')

# Diagrama de barras horizontales
plt.subplot(2, 2, 2)
frecuencia_absoluta.plot(kind='barh', color='orange', alpha=0.7)
plt.title('Diagrama de Barras Horizontales')
plt.xlabel('Frecuencia Absoluta')
plt.ylabel('Valores')

# Polígono de frecuencia
plt.subplot(2, 2, 3)
plt.plot(frecuencia_relativa.index, frecuencia_relativa.values, marker='o', color='green')
plt.title('Polígono de Frecuencia Relativa')
plt.xlabel('Valores')
plt.ylabel('Frecuencia Relativa')

# Diagrama de pastel
plt.subplot(2, 2, 4)
plt.pie(frecuencia_relativa, labels=frecuencia_relativa.index, autopct='%1.1f%%', startangle=140)
plt.title('Diagrama de Pastel de Frecuencia Relativa')

plt.tight_layout()
plt.show()

# Graficar la ojiva
plt.figure(figsize=(8, 6))
plt.plot(frecuencia_acumulada.index, frecuencia_acumulada.values, marker='o', color='purple')
plt.title('Ojiva de Frecuencia Acumulada')
plt.xlabel('Valores')
plt.ylabel('Frecuencia Acumulada')
plt.grid()
plt.show()
